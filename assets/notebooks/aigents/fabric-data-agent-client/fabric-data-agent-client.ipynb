# %% [markdown]
# # Fabric Data Agent SDK Client
#
# Usando o Data Agent do Fabric externo ao Fabric Cluster.

# %% [markdown]
# # Carregar variáveis do arquivo .env de um diretório específico
# env_path = "../../../.env"
# load_dotenv(dotenv_path=env_path)
